# %% [markdown]
# # Sentiment Convergence Analysis
#
# **Project:** MLLM Persona Simulation — UrbCom 2026
# **Input:** `outputs/annotations_baseline.jsonl`
# **RQ1:** Do MLLM personas sharing the same demographic profile converge toward
# the same sentiment label when independently evaluating the same image?
#
# Implementation lives in [`src/utils/convergence.py`](../src/utils/convergence.py).

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from utils import convergence as conv
from utils.common import setup_theme

palette = setup_theme(font_scale=1.5)

# %%
df_base, gt_modal, profile_map = conv.load_inputs()
df_base = conv.prepare(df_base, "baseline", profile_map, gt_modal)
df_base[["condition", "image_id", "persona_id", "profile_id",
         "predicted_sentiment", "human_sentiment"]].head()

# %%
conv_base = conv.within_group_convergence(df_base)
metrics_base = conv.compute_gt_metrics(df_base, gt_modal, "baseline")

# %%
conv.plot_image_dataset_distribution(gt_modal, df_base, palette)
conv.plot_sentiment_distribution_baseline(df_base, gt_modal, palette)
conv.plot_confusion_matrix_baseline(df_base, gt_modal)
conv.plot_modal_ratio_heatmap_economic(df_base, conv_base)

# %%
profile_meta = conv.load_profile_meta()
conv.plot_profile_sentiment_heatmap(df_base, profile_meta)
modal_df = conv.compute_modal_df(df_base, profile_meta)
conv.plot_modal_ratio_by_profile(modal_df)
conv.plot_convergence_by_dimension(modal_df, profile_meta, palette)

# %%
table2 = conv.summary_table(conv_base, df_base, metrics_base)
table2
